# %% [markdown]
# The dataset for fine-tuning is the [Financial Phrase Bank Dataset](https://www.researchgate.net/publication/251231364_FinancialPhraseBank-v10) that was collected by [Maloet al, 2014](https://arxiv.org/abs/1307.5336)
#
# The reason for choosing this dataset is because it consists of 4845 english sentences selected randomly from financial news, labeled according to how the information contained might affect the mentioned company stock price: positive, negative or neutral. The dataset is available in four possible configurations depending on the percentage of agreement of annotators, however, we will use file `Sentences_50Agree.txt` as this file contains the most complete data.
#
# This picture below depicts how how text is classified in the datase:
# ![image.png](attachment:image.png)
# *Source: Good Debt or Bad Debt: Detecting Semantic Orientations in Economic Texts*

# %% [markdown]
# # Import

# %%
#import packages
import pandas as pd
import numpy as np

from collections import Counter

import re                                  # library for regular expression operations
import string                              # for string operations

from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import TweetTokenizer   # module for tokenizing strings

# %%
# import dataset
path_50 = '/Users/hienanh/Documents/GitHub/Model/Sentences_50Agree.txt'
df = pd.read_csv(path_50, sep="@",encoding="ISO-8859-1", names = ['sentence', 'label'])
df.head()
# Out:
#                                             sentence     label
# 0  According to Gran , the company has no plans t...   neutral
# 1  Technopolis plans to develop in stages an area...   neutral
# 2  The international electronic industry company ...  negative
# 3  With the new production plant the company woul...  positive
# 4  According to the company 's updated strategy f...  positive

# %%
df.isnull().sum()
# Out:
# sentence    0
# label       0
# dtype: int64

# %%
Counter(df['label'].tolist())
# Out:
# Counter({'neutral': 2879, 'negative': 604, 'positive': 1363})

# %% [markdown]
# # Vectorizers: Bag of words

# %%
#import packages
import pandas as pd
import numpy as np

from collections import Counter

import re                                  # library for regular expression operations
import string                              # for string operations

from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import TweetTokenizer   # module for tokenizing strings

# %%
# import dataset
path_50 = '/Users/hienanh/Documents/GitHub/Model/Sentences_50Agree.txt'
df_50 = pd.read_csv(path_50, sep="@",encoding="ISO-8859-1", names = ['sentence', 'label'])
df_50.head()
# Out:
#                                             sentence     label
# 0  According to Gran , the company has no plans t...   neutral
# 1  Technopolis plans to develop in stages an area...   neutral
# 2  The international electronic industry company ...  negative
# 3  With the new production plant the company woul...  positive
# 4  According to the company 's updated strategy f...  positive

# %%
# pre-processing 
## clean text
def process_text(text):
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    #text = text.str
    text = re.sub(r'\$\w*', '', text)
    text = re.sub(r'^RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'#', '', text)
    tokenizer = TweetTokenizer(preserve_case=False,        strip_handles=True,reduce_len=True)
    text_tokens = tokenizer.tokenize(text)

    text_clean = []
    for word in text_tokens:
        if (word not in stopwords_english and  
                word not in string.punctuation): 
            stem_word = stemmer.stem(word)  # stemming word
            text_clean.append(stem_word)
            
    text_clean_2 = ' '.join(text_clean)

    return text_clean_2

## quantify label 
def encode(label):
    if label == 'negative':
        value = -1
    elif label == 'neutral':
        value = 0
    elif label == 'positive':
        value = 1
    return value

# %%
df_50['clean_text'] = df_50['sentence'].apply(lambda x: process_text(x))
df_50['sentiment'] = df_50['label'].apply(lambda x: encode(x))
df_50
# Out:
#                                                sentence     label  \
# 0     According to Gran , the company has no plans t...   neutral
# 1     Technopolis plans to develop in stages an area...   neutral
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# ...                                                 ...       ...
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
#                                              clean_text  sentiment
# 0     accord gran compani plan move product russia a...          0
# 1     technopoli plan develop stage area less 100,00...          0
# 2     intern electron industri compani elcoteq laid ...         -1
# 3     new product plant compani would increas capac ...          1
# 4     accord compani updat strategi year 2009-2012 b...          1
# ...                                                 ...        ...
# 4841  london marketwatch share price end lower londo...         -1
# 4842  rinkuskiai beer sale fell 6.5 per cent 4.16 mi...          0
# 4843  oper profit fell eur 35.4 mn eur 68.8 mn 2007 ...         -1
# 4844  net sale paper segment decreas eur 221.6 mn se...         -1
# 4845  sale finland decreas 10.5 januari sale outsid ...         -1
#
# [4846 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

X=df_50['clean_text'].values
Y=df_50['sentiment'].values
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.3, random_state=254)

X_train
# Out:
# array(['initi estim total valu contract 250 000 euro exclud vat',
#        'payment 2.779 million lita interest long-term loan provid raguti major sharehold estonia le coq also ad loss',
#        'finnish ac drive manufactur vacon acquir ac drive busi tb wood part us group altra hold',
#        ...,
#        'offer 30 million share aim rais x20ac 500 million us 640 million expect complet oct 9 outokumpu said',
#        'net profit period 2009 euro 29 million',
#        'accord mark white locatrix commun ceo compani web servic interfac allow devic owner friend famili track locat twig user via web browser'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(strip_accents='unicode', 
                             analyzer='word', 
                             ngram_range=(1,3), 
                             norm='l2')
vectorizer.fit(X_train)
vectorizer.fit(X_test)
# Out:
# TfidfVectorizer(ngram_range=(1, 3), strip_accents='unicode')

# %%
x_train = vectorizer.transform(X_train)
x_test = vectorizer.transform(X_test)
x_train
# Out:
# <3392x34472 sparse matrix of type '<class 'numpy.float64'>'
# 	with 52320 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression(random_state=0,multi_class='ovr').fit(x_train, Y_train)
prediction = model.predict(x_test)
accuracy_score(Y_test, prediction)
# Out:
# 0.6836313617606602

# %%
Counter(prediction)
# Out:
# Counter({0: 1320, 1: 104, -1: 30})

# %%
file_list = ['participants_1.csv','participants_2.csv',
             'participants_3.csv','participants_4.csv']

# %%
def test(file_list):
    list_text = []
    for file in file_list:
        path_dir = '/Users/hienanh/Desktop/Cass/ARP/text_data/'
        path = path_dir + file
        participants = pd.read_csv(path)
        text = participants.iloc[0,1]
        test = process_text(text)
        list_text.append(test)
    
    return list_text

# %%
test = test(file_list)
test
# Out:
# ["ye thank uli good thing interfac surround somi read glass broke 15 minut meet axel kind enough toget qualiti uk product drugstor next corner i'm onlin thank you.thank uli think mention alreadi part – major part keyfigur result think start – get detail p l look key metric remark develop key metric whichwer driven us also market ezb whomsoever.first strong cash flow 2014 nearli reach € 2 billion mark westart littl bit slow year think mention previou occas wason u mobil contract might come contract littl bit later whichwa cash neg first two quarter turnaround – alreadi willturnaround 2015 get money back second half year verystrong cash flow think support posit messag qualiti theresult even littl bit depress overal growth cash flow stay verypositive.on right hand side asset manag 14 € 4.5 billion cantel develop u dollar yield especi yield thegovern bond today approach € 39 billion increas reallyremark driven good result also yield andespeci currenc exchang rates.th goe capit posit next slide equiti increas nearli € 1.7 billion 28 policyhold surplu € 1.5 billion littl bit differ paid back € 750 million februari issu subordin bond issu new-subordin bond septemb anoth € 500 million whichthen reason policyhold surplu decreas subordinatedbond decreas littl bit.you might rememb anoth call date come june € 500 million tonow indic last € 500 million alreadi earli refinanc anannounc call call everi subordinatedbond first call date one might expect green part bar might godown june.on side slide see increas sharehold equiti thinkthat demonstr clearli increas – strong increas come from.first cours € 986 million result dividend paid last year € 362million demonstr increas come valuat reserv onour invest asset well currenc exchang rate billioneuro even higher produc profits.now might want distinguish two compon increas theincreas asset currenc exchang rate think also reflect theearn side higher u dollar aussi dollar whatev earn earn alsohigh euro valu amount look valuat reserv morethan € 630 million middl increas realli increas capitalbas also impact futur rois.th overal number oci capit driven valuat reserv assetportfolio € 1.2 billion nearli modifi durat five year one could expect everyth equal might lose € 120 million per year run becapit compon disappear futur € 120 million per year think lead us directli capit manag action uli alreadyment see point view impress pictur look thelast six year six year ago came mention intent todecreas volatil earn decreas volatil dividend payments.and look pictur see we'r rather success coursehelp market also catastroph compon busi even ifin 2011 second highest natur catastroph burden histori ofreinsur manag provid good dividend.th € 3 plu bonu repres € 150 million kind give back toour sharehold start potenti capit manag action dividend yieldtoday day ago 5 go back begin year 6 goback one year invest hannov share one year ago thedividend yield would even 7 one perspect capit develop roe provid anddo provid think chart demonstr clearli achiev averag capitalposit increas remark € 4 billion € 6.7 billion year.stil manag keep roe high level.on right-hand side see averag achiev left-hand side lastfiv year margin hurdl shown old hurdl is750 basi point well new hurdl 900 basi point even increas overth last year' bear mind got challeng thefutur high capit posit also higher volatil capit compon tri explain oci posit might volatil future.so go challeng futur also look atmanag capit posit well incom posit think lead us directli peer comparison alway think wear still number one four-year horizon year two bermudian compani arein front us think surpris low cap burdenwhich industri see regard still happi stillcommit stay one profit reinsur industri also future.so let' brief look p l detail group level think notnecessari repeat growth turnov premium first compon ithink need explan incom expens line havebeen long u dollar non-euro currenc alreadi cours theyear far major swing minu € 100 million plu € 18 million inth expens  ...
#  "well good afternoon everybodi london good afternoon depend onyour time day join us via internet go give youa remind turn mobil phone easi forget pleas docheck off.that said welcom hannov re' analyst confer pleasur see somani taken invit delight present thenumb financi year 2014 greater detail number havepublish alreadi morning.today new featur compar previou analyst confer areoff addit dial-in option abl particip herephys london stock exchang remind dialed-in particip willb listen-onli mode.first ulrich wallin kick thing brief overview 2014 financi year.roland vogel cfo move present financi detail afterward happi respond length question might iwould like point kindli ask wait microphon thateverybodi understand question even room.on note delight hand ulrich wallin.okay anoth question come confer call come frommichael haid",
#  "well thank much begin question-and-answ session aremind pleas wait microphon everybodi hear question especi particip via confer call proceed take thequest particip room first switch questionscom confer call alreadi see hand start righthand side ben q aokay question confer call anyoth question come room we'd like thank attend we'd like conclud call may disconnect it.for other room would like cordial invit behalf ofhannov snack refresh outsid room thank forattend thank come",
#  "three quick question one follow-up last answer understand thenwhi diversif benefit page 84 gone 51 reduc thediversif come overal proport gross capitalrequir gone think 32 36 okay two quick question look life reinsur busi andyour mcev disclosur last five year there' short € 800 million ofneg oper varianc assumpt chang relat u uk longev australian dii continu express lot confid life result improv andalso ev translat ifr profit bit hard us kind see given theamount sort assumpt chang varianc go somayb think need thorough kind ground-up review ofassumpt we'v realli pass worst particularli u still find hard toget comfort outlook there.th question think implic book unusedbudget larg loss want us think roland € 200roughli million unus henc that' what' drive sort slight increas inreserv buffer thank"]

# %%
test_vecto = vectorizer.transform(test)
prediction_test = model.predict(test_vecto)
prediction_test
# Out:
# array([1, 0, 0, 0])

# %%
Counter(prediction)
# Out:
# Counter({0: 1320, 1: 104, -1: 30})

# %%
path_dir = '/Users/hienanh/Desktop/Cass/ARP/text_data/'
new_path = path_dir + file_list[3]
text_check = pd.read_csv(new_path)
text_check.iloc[0,1]
# Out:
# "Three quick questions. One is just a follow-up on your last answer. I don't understand thenwhy the diversification benefit on page 84 has gone up 51%, if you reduced thediversification to how come the overall, and as a proportion of the gross capitalrequirement gone up, I think from 32% to 36%, so?Okay. And the two other quick questions. If I look at your life reinsurance business andyour MCEV disclosure over the last five years, there's been just short of €800 million ofnegative operating variances or assumption changes related to U.S., UK, longevity,Australian DII. You continue to express a lot of confidence in the Life result improving, andalso in your EV translating to IFRS profits. It's a bit hard for us to kind of see that, given theamount of sort of assumption changes and variances that have been going through. Somaybe do you think you need to do a more thorough kind of ground-up review again ofassumptions? Or we've really passed the worst on particularly the U.S.? I still find it hard toget comfortable with the outlook there.The only other question I have, I think the implication is that you booked the unusedbudget on large losses. Is that how you want us to think about, Roland, as in the €200roughly-million of unused? And hence that's what's driving the sort of slight increase inreserve buffer again? Thanks."
